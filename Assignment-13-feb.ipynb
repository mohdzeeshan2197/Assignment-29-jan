# %% [markdown]
# # Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# 1.Explain why we have to use the Exception class while crating a custom Exception.
# Ans-
#     In python,the built-in'Exception'class is the base class for all exceptions. when we create a custom exception,we usually want it to behave like a standard exception and be compatible with the existing exception handling mechanism in python.To achieve this,we need to inherit our custom exception class from the'exception' class, By inheriting from the 'exception'class our custom exception inherits all the functionality of base class,such as the ability to print a traceback,get a message string,and interact with other exceptions.This allows us to use our custom exception in the same way as the built-in exceptions,with the same 'try-except'block syntax. In addition,by inheriting from the'Exception' class,we can make use of the built-in exception hierarchy in python.This means that our custom exception can be part of larger hierarchy of exceptions,with more specific exceptions inheriting from more general ones.This makes it easier to organize and handle different types of exception in our code.

# %% [markdown]
# # Q2. Write a python program to print Python Exception Hierarchy.

# %%
# import inspect
  
# our treeClass function
def treeClass(cls, ind = 0):
    
      # print name of the class
    print ('-' * ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
  
# inspect.getmro() Return a tuple 
# of class  cls’s base classes.
  
# building a tree hierarchy 
inspect.getclasstree(inspect.getmro(BaseException))
  
# function call
treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- herror
# --------- gaierror
# --------- timeout
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %% [markdown]
# # Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# AirthmeticError class is the base class for all error associated with
#
# 1. ZeroDivisionError,
# 2. OverFlowError,
# 3. FloatingPointError

# %%
# 1.zerodivisionError

import logging
logging.basicConfig(filename = 'eeee.log',level = logging.ERROR)
try :
    5/0
except ZeroDivisionError as e:
    logging.error("Your Error in my record {}".format(e))

# %%
# 2. OverFlowError

j = 5.0

try:
    for i in range(1, 1000):
        j = j**i
except ArithmeticError as e:
    print(f"{e}, {e.__class__}")
# Out:
# (34, 'Result too large'), <class 'OverflowError'>

# %% [markdown]
# # Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# LookupError class is the base class for raise error when something cannt be found,the base class for the exceptions that are raised when a key or index used on the mapping or sequence is invalid . Indexerror , KeyError an IndexError  is raised when a sequence reference is out of range.

# %% [markdown]
# # Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# An ImportError is detected when Python has problems with a successful module import. Usually this problem is caused by the incorrect path and is usually displayed with the message that there is “No module named (…)” or “cannot import name (…)”.

# %% [markdown]
# ModuleNotFoundError is the error that occur when python doesnot find that module which you are trying

# %% [markdown]
# # Q6. List down some best practices for exception handling in python.

# %% [markdown]
# 1.Catch Specific exceptions
# 2.Use try-except blocks
# 3.Use finally block
# 4.Raise exception
# 5.provide useful error messages
# 6.Log the exceptions
# 7.Use context managers
# 8.Test exception handling
