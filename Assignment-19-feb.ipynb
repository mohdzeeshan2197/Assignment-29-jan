# %% [markdown]
# # Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a web application framework written in Python. Flask is based on the Werkzeug WSGI toolkit and Jinja2 template engine. Both are Pocco projects Advantages of Flask The flask is a micro-framework for web development, so developing and maintaining websites is very easy. Routing URLs in Flask is very easy to implement. As flask comes with basic tools, so the learning curve for this framework is easy and small.

# %% [markdown]
# # Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)


@app.route("/f")
def fun():
    return "Hello World"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.43.178:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![Screenshot%20%2822%29.png](attachment:Screenshot%20%2822%29.png)

# %% [markdown]
# # Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing means mapping the URL to specific function that will handle the logic for that URLs Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler.

# %% [markdown]
# # Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
from flask import Flask


app = Flask( __name__)

@app.route("/welcome")
def fun1():
    return "Welcome to ABC Coporation"
@app.route("/")
def fun2():
    return  "<h1>Company Information</h1><p>Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999</p>"


if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.43.178:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![Screenshot%20%2823%29.png](attachment:Screenshot%20%2823%29.png)

# %% [markdown]
# ![Screenshot%20%2825%29.png](attachment:Screenshot%20%2825%29.png)

# %% [markdown]
# # Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.

# %%
from flask import Flask,redirect, url_for

app = Flask(__name__)

@app.route("/")
def welcome():
    return "Welcome To PWskills Site"

@app.route("/student")
def student():
    return "Hello Students To kaise hai aaplog"

@app.route("/faculty")
def faculty():
    return "Hello Teacher's Welocome to pwskill Faculty"
@app.route("/user/<name>")
def user(name):
    if name == "student":
        return redirect(url_for("student"))
    if name == "faculty":
        return redirect(url_for("faculty"))

if __name__=="__main__":
    app.run(debug=True)

# %% [markdown]
# ![Screenshot%20%2826%29.png](attachment:Screenshot%20%2826%29.png)

# %% [markdown]
# ![Screenshot%20%2827%29.png](attachment:Screenshot%20%2827%29.png)
